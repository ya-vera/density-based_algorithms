# %% [markdown]
# # Синтетические датасеты - бэйзлайн (дефолтные параметры)
#
# Алгоритмы без подбора параметров.

# %%
import sys, time, warnings
import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.metrics import (
    adjusted_rand_score, adjusted_mutual_info_score,
    normalized_mutual_info_score, fowlkes_mallows_score,
    silhouette_score, davies_bouldin_score, calinski_harabasz_score,
)

sys.path.insert(0, '..')
warnings.filterwarnings('ignore')
from data_generator.classic_shapes import load_sipu_shapes

# %%
from algorithms import (
    DBSCANWrapper, HDBSCANWrapper,
    DPCWrapper, RDDACWrapper, CKDPCWrapper,
)

ALG_NAMES = ['DBSCAN', 'HDBSCAN', 'DPC', 'RD-DAC', 'CKDPC']
ALG_CLASSES = {
    'DBSCAN':  DBSCANWrapper,
    'HDBSCAN': HDBSCANWrapper,
    'DPC':     DPCWrapper,
    'RD-DAC':  RDDACWrapper,
    'CKDPC':   CKDPCWrapper,
}

# %%
try:
    DATASETS = load_sipu_shapes()
    print("Loaded SIPU datasets:", [d.name for d in DATASETS])
except FileNotFoundError as e:
    print(f"SIPU not found: {e}")
    DATASETS = []
# Out:
# Loaded SIPU datasets: ['shape_flame', 'shape_jain', 'shape_spiral', 'shape_aggregation', 'shape_r15', 'shape_d31']

# %%
def compute_all_metrics(X, labels, y_true):
    labels  = np.asarray(labels, dtype=int)
    y_true  = np.asarray(y_true, dtype=int)
    mask_nn = labels != -1
    k_found   = len(set(labels[mask_nn].tolist())) if mask_nn.any() else 0
    noise_pct = float((~mask_nn).sum()) / len(labels) * 100
    if k_found >= 2:
        ari = float(adjusted_rand_score(y_true, labels))
        ami = float(adjusted_mutual_info_score(y_true, labels))
        nmi = float(normalized_mutual_info_score(y_true, labels))
        fmi = float(fowlkes_mallows_score(y_true, labels))
    elif k_found == 1:
        ari = ami = nmi = fmi = 0.0
    else:
        ari = ami = nmi = fmi = float('nan')
    X_sub, l_sub = X[mask_nn], labels[mask_nn]
    if mask_nn.sum() >= 2 and len(np.unique(l_sub)) >= 2:
        try:    sc  = float(silhouette_score(X_sub, l_sub))
        except: sc  = float('nan')
        try:    chi = float(calinski_harabasz_score(X_sub, l_sub))
        except: chi = float('nan')
        try:    dbi = float(davies_bouldin_score(X_sub, l_sub))
        except: dbi = float('nan')
    else:
        sc = chi = dbi = float('nan')
    return dict(k_found=k_found, noise_pct=noise_pct,
                ARI=ari, AMI=ami, NMI=nmi, FMI=fmi, SC=sc, CHI=chi, DBI=dbi)


def run_default(alg_class, X):
    try:
        return np.asarray(alg_class().fit_predict(X), dtype=int)
    except Exception as e:
        print(f'  ERROR: {e}')
        return np.zeros(len(X), dtype=int)

# %%
def show_results(all_results, datasets):
    summary = []
    for ds in datasets:
        dname = ds.name
        k_true = len(np.unique(ds.y_true))
        for alg in ALG_NAMES:
            m = all_results[dname][alg]
            def _v(k): return round(m[k], 4) if isinstance(m[k], float) and m[k]==m[k] else None
            summary.append({'Dataset': dname, 'k_true': k_true,
                            'Algorithm': alg, 'k_found': m['k_found'],
                            'noise%': round(m['noise_pct'],1),
                            'ARI': _v('ARI'), 'AMI': _v('AMI'), 'NMI': _v('NMI'),
                            'FMI': _v('FMI'), 'SC': _v('SC'), 'CHI': _v('CHI'), 'DBI': _v('DBI')})
    df = pd.DataFrame(summary)
    display(df.set_index(['Dataset','Algorithm']).style
            .format({'ARI':'{:.4f}','AMI':'{:.4f}','NMI':'{:.4f}',
                     'FMI':'{:.4f}','SC':'{:.4f}','DBI':'{:.4f}',
                     'noise%':'{:.1f}'}, na_rep='-')
            .background_gradient(subset=['ARI', 'AMI', 'NMI', 'FMI'], cmap='RdYlGn', vmin=0, vmax=1)
            .set_caption('Полная таблица метрик'))

# %%
ALL_RESULTS = {}
for ds in DATASETS:
    X, y = ds.X, ds.y_true
    print(f'\n{ds.name}  [{X.shape[0]} x {X.shape[1]}]  k_true={len(np.unique(y))}')
    rows = {}
    for alg_name in ALG_NAMES:
        t0     = time.time()
        labels = run_default(ALG_CLASSES[alg_name], X)
        mets   = compute_all_metrics(X, labels, y)
        elapsed = time.time() - t0
        rows[alg_name] = mets
        print(f'  {alg_name:<8}  k={mets["k_found"]}  noise={mets["noise_pct"]:.1f}%  '
              f'ARI={mets["ARI"]:.4f}  ({elapsed:.1f}s)')
    ALL_RESULTS[ds.name] = rows
# Out:
# shape_flame  [240 x 2]  k_true=2
#   DBSCAN    k=9  noise=42.1%  ARI=0.1040  (0.0s)
#   HDBSCAN   k=2  noise=12.5%  ARI=0.7737  (0.0s)
#   DPC       k=7  noise=0.0%  ARI=0.3306  (0.0s)
#   RD-DAC    k=4  noise=0.0%  ARI=0.1354  (0.0s)
#   CKDPC     k=3  noise=2.5%  ARI=0.0206  (0.0s)
#
# shape_jain  [373 x 2]  k_true=2
#   DBSCAN    k=19  noise=37.5%  ARI=0.0068  (0.0s)
#   HDBSCAN   k=9  noise=3.5%  ARI=0.8800  (0.0s)
#   DPC       k=9  noise=0.0%  ARI=0.1326  (0.0s)
#   RD-DAC    k=3  noise=0.0%  ARI=0.3802  (0.0s)
#   CKDPC     k=7  noise=11.0%  ARI=0.8539  (0.0s)
#
# shape_spiral  [312 x 2]  k_true=3
#   DBSCAN    k=5  noise=35.3%  ARI=0.3893  (0.0s)
#   HDBSCAN   k=3  noise=0.0%  ARI=1.0000  (0.0s)
#   DPC       k=4  noise=0.0%  ARI=0.9322  (0.0s)
#   RD-DAC    k=5  noise=0.0%  ARI=0.0296  (0.0s)
#   CKDPC     k=6  noise=4.5%  ARI=0.7462  (0.0s)
#
# shape_aggregation  [788 x 2]  k_true=7
#   DBSCAN    k=9  noise=5.3%  ARI=0.9107  (0.0s)
#   HDBSCAN   k=5  noise=0.0%  ARI=0.8089  (0.0s)
#   DPC       k=10  noise=0.0%  ARI=0.6628  (0.0s)
#   RD-DAC    k=5  noise=0.0%  ARI=0.8261  (0.0s)
#   CKDPC     k=6  noise=8.5%  ARI=0.8193  (0.1s)
#
# shape_r15  [600 x 2]  k_true=15
#   DBSCAN    k=19  noise=35.8%  ARI=0.2387  (0.0s)
#   HDBSCAN   k=15  noise=1.2%  ARI=0.9690  (0.0s)
#   DPC       k=16  noise=0.0%  ARI=0.9770  (0.0s)
#   RD-DAC    k=16  noise=0.0%  ARI=0.9537  (0.0s)
#   CKDPC     k=16  noise=9.0%  ARI=0.8321  (0.1s)
#
# shape_d31  [3100 x 2]  k_true=31
#   DBSCAN    k=46  noise=15.7%  ARI=0.5164  (0.2s)
#   HDBSCAN   k=85  noise=17.5%  ARI=0.4203  (0.1s)
#   DPC       k=32  noise=0.0%  ARI=0.9325  (0.4s)
#   RD-DAC    k=2  noise=0.0%  ARI=0.0240  (0.3s)
#   CKDPC     k=7  noise=8.0%  ARI=0.2125  (0.9s)

# %%
show_results(ALL_RESULTS, DATASETS)
# Out:
# <style type="text/css">
# #T_8fc74_row0_col3 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_8fc74_row0_col4 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_8fc74_row0_col5 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_8fc74_row0_col6 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_8fc74_row1_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_8fc74_row1_col4, #T_8fc74_row1_col5 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_8fc74_row1_col6, #T_8fc74_row16_col4, #T_8fc74_row16_col5 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_8fc74_row2_col3 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_8fc74_row2_col4 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_8fc74_row2_col5 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_8fc74_row2_col6 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_8fc74_row3_col3 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_8fc74_row3_col4, #T_8fc74_row20_col6 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_8fc74_row3_col5 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_8fc74_row3_col6 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_8fc74_row4_col3 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_8fc74_row4_col4 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_8fc74_row4_col5 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_8fc74_row4_col6 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_8fc74_row5_col3 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_8fc74_row5_col4, #T_8fc74_row28_col6 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_8fc74_row5_col5, #T_8fc74_row28_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_8fc74_row5_col6 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_8fc74_row6_col3 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_8fc74_row6_col4 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_8fc74_row6_col5, #T_8fc74_row20_col5 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_8fc74_row6_col6 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_8fc74_row7_col3 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_8fc74_row7_col4 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_8fc74_row7_col5 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_8fc74_row7_col6, #T_8fc74_row26_col3 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_8fc74_row8_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_8fc74_row8_col4 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_8fc74_row8_col5 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_8fc74_row8_col6 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_8fc74_row9_col3, #T_8fc74_row18_col4 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_8fc74_row9_col4, #T_8fc74_row17_col6 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_8fc74_row9_col5, #T_8fc74_row14_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_8fc74_row9_col6, #T_8fc74_row12_col4, #T_8fc74_row12_col5 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_8fc74_row10_col3 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_8fc74_row10_col4 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_8fc74_row10_col5 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_8fc74_row10_col6 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_8fc74_row11_col3, #T_8fc74_row11_col4, #T_8fc74_row11_col5, #T_8fc74_row11_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8fc74_row12_col3, #T_8fc74_row15_col6, #T_8fc74_row27_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_8fc74_row12_col6, #T_8fc74_row23_col3, #T_8fc74_row23_col6, #T_8fc74_row27_col4, #T_8fc74_row27_col5 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_8fc74_row13_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_8fc74_row13_col4 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_8fc74_row13_col5 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_8fc74_row13_col6 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_8fc74_row14_col4 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_8fc74_row14_col5 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_8fc74_row14_col6, #T_8fc74_row18_col3 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_8fc74_row15_col3, #T_8fc74_row15_col5 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_8fc74_row15_col4 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_8fc74_row16_col3 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_8fc74_row16_col6, #T_8fc74_row17_col4 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_8fc74_row17_col3 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_8fc74_row17_col5, #T_8fc74_row18_col6 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_8fc74_row18_col5, #T_8fc74_row19_col6 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_8fc74_row19_col3, #T_8fc74_row25_col5 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_8fc74_row19_col4 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_8fc74_row19_col5, #T_8fc74_row24_col6 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_8fc74_row20_col3 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_8fc74_row20_col4 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_8fc74_row21_col3, #T_8fc74_row21_col4, #T_8fc74_row21_col6, #T_8fc74_row23_col5 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_8fc74_row21_col5 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_8fc74_row22_col3, #T_8fc74_row22_col6 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_8fc74_row22_col4, #T_8fc74_row22_col5 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_8fc74_row23_col4 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_8fc74_row24_col3 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_8fc74_row24_col4 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_8fc74_row24_col5 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_8fc74_row25_col3 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_8fc74_row25_col4 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_8fc74_row25_col6 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_8fc74_row26_col4 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_8fc74_row26_col5 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_8fc74_row26_col6 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_8fc74_row27_col6 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_8fc74_row28_col3 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_8fc74_row28_col4 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_8fc74_row29_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_8fc74_row29_col4 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_8fc74_row29_col5 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_8fc74_row29_col6 {
#   background-color: #feca79;
#   color: #000000;
# }
# </style>
# <table id="T_8fc74">
#   <caption>Полная таблица метрик</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fc74_level0_col0" class="col_heading level0 col0" >k_true</th>
#       <th id="T_8fc74_level0_col1" class="col_heading level0 col1" >k_found</th>
#       <th id="T_8fc74_level0_col2" class="col_heading level0 col2" >noise%</th>
#       <th id="T_8fc74_level0_col3" class="col_heading level0 col3" >ARI</th>
#       <th id="T_8fc74_level0_col4" class="col_heading level0 col4" >AMI</th>
#       <th id="T_8fc74_level0_col5" class="col_heading level0 col5" >NMI</th>
#       <th id="T_8fc74_level0_col6" class="col_heading level0 col6" >FMI</th>
#       <th id="T_8fc74_level0_col7" class="col_heading level0 col7" >SC</th>
#       <th id="T_8fc74_level0_col8" class="col_heading level0 col8" >CHI</th>
#       <th id="T_8fc74_level0_col9" class="col_heading level0 col9" >DBI</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Algorithm</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</t
